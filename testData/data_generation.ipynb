# %% [markdown]
# Data generation code

# %%
import pandas as pd
import random
from openpyxl import Workbook
import ast

# %%
# Function to generate random data based on the column specifications
# column_spec = {"name": column name, "list": [list of strings], "min": min value, "max": max value}
def generate_data(column_spec):
    name = column_spec.get('name', None)
    min_val = column_spec.get('min', None)
    max_val = column_spec.get('max', None)

    if 'list' in column_spec:
        data_list = column_spec['list']
        
        
        if min_val is not None and max_val is not None:
            random_data = random.choices(data_list, k=1)
            if random.uniform(0, 1) < 0.9:  # 90% chance of getting a random value
                value = random.uniform(min_val, max_val)
                if name == "Record ID" or name == "Renal Status" or "BP prior to blood draw" in name:
                    value = round(value)
                return value
            return random_data[0]
        else:
            return random.choice(data_list)

    elif min_val is not None and max is not None:
        value = random.uniform(min_val, max_val)
        if name == "Age":
            value = round(value)
        return value

    else:
        return random.uniform(0, 1)  # Default for all numerical data

# %%
# Read the data from the text file
with open('./data/data_shape.txt', 'r') as file:
    lines = file.readlines()
lines
# Out:
# ['Record ID:\n',
#  "['T21-2', 'T21-3', 'T21-4', 'T21-5', 'T21-7', 'T21-9', 'T21-10', 'T21-12', 'T21-13', 'T21-14', 'T21-15', 'T21-16', 'T21-17', 'T21-18', 'T21-19', 'T21-22', 'T21-23', 'T21-24', 'T21-25', 'T21-26', 'T21-27', 'T21-28', 'T21-29', 'T21-30', 'T21-31', 'T21-32', 'T21-33', 'T21-34', 'T21-35', 'T21-36', 'T21-37', 'T21-39', 'T21-40', 'T21-41', 'T21-42', 'T21-43', 'T21-44', 'T21-45', 'T21-46', 'T21-47', 'T21-48', 'T21-49', 'T21-50', 'T21-52', 'T21-53', 'T21-54', 'T21-55', 'T21-57', 'T21-58', 'T21-59', 'T21-60', 'T21-61', 'T21-62', 'T21-63', 'T21-64', 'T21-65', 'T21-66', 'T21-67', 'T21-68', 'T21-69', 'T21-70']\n",
#  'min value 2\n',
#  'max value 195\n',
#  '\n',
#  'Age:\n',
#  'min value 60\n',
#  'max value 92\n',
#  '\n',
#  'Sex:\n',
#  "['Male', 'Female']\n",
#  '\n',
#  'White:\n',
#  '[1, 0]\n',
#  '\n',
#  'Extremity:\n',
#  "['right', 'left', 'Bilateral']\n",
#  '\n',
#  'Artery affected:\n',
#  "['common femoral, anterior tibial, external iliac', 'SFA, anterior tibial, posterior tibial', 'SFA, popliteal', 'SFA, anterior tibial', 'common femoral, anterior tibial, posterior tibial', 'common femoral, SFA, aortoiliac', 'common femoral, SFA, popliteal, anterior tibial, posterior tibial, aortoiliac', 'common femoral, popliteal, posterior tibial, aortoiliac', 'common femoral, anterior tibial, aortoiliac', 'common femoral, anterior tibial', 'SFA, popliteal, anterior tibial, aortoiliac', 'common femoral, external iliac', 'common femoral, popliteal, anterior tibial', 'SFA', 'common femoral, SFA', 'SFA, popliteal, aortoiliac', 'common femoral, anterior tibial, posterior tibial, internal iliac', 'common femoral, posterior tibial, internal iliac', 'common femoral, popliteal', 'common femoral, SFA, anterior tibial, aortoiliac', 'common femoral, anterior tibial, external iliac, internal iliac', 'common femoral, SFA, popliteal', 'common femoral, internal iliac', 'SFA, anterior tibial, aortoiliac', 'SFA, external iliac', 'common femoral, external iliac, internal iliac', 'common femoral, anterior tibial, internal iliac', 'common femoral, SFA, popliteal, anterior tibial, aortoiliac', 'SFA, posterior tibial', 'SFA, aortoiliac', 'common femoral, popliteal, anterior tibial, aortoiliac', 'common femoral, SFA, popliteal, aortoiliac', 'SFA, internal iliac', 'common femoral, SFA, posterior tibial, aortoiliac', 'SFA, anterior tibial, posterior tibial, internal iliac', 'common femoral, popliteal, aortoiliac', 'common femoral, popliteal, anterior tibial, posterior tibial, external iliac', 'SFA, anterior tibial, posterior tibial, external iliac', 'SFA, popliteal, posterior tibial', 'SFA, popliteal, posterior tibial, aortoiliac', 'common femoral, SFA, popliteal, anterior tibial', 'SFA, external iliac, internal iliac', 'SFA, posterior tibial, external iliac', 'SFA, popliteal, anterior tibial, posterior tibial', 'common femoral', 'external iliac', 'common femoral, aortoiliac', 'common femoral, SFA, popliteal, anterior tibial, posterior tibial, internal iliac', 'popliteal', 'anterior tibial, posterior tibial', 'common femoral, SFA, external iliac', 'anterior tibial', 'common femoral, SFA, popliteal, posterior tibial, external iliac, internal iliac', 'popliteal, anterior tibial', 'SFA, popliteal, anterior tibial', 'common femoral, external iliac, aortoiliac', 'popliteal, anterior tibial, posterior tibial', 'popliteal, posterior tibial', 'aortoiliac', 'common femoral, SFA, popliteal, external iliac, aortoiliac', 'popliteal, anterior tibial, posterior tibial, peroneal', 'common femoral, SFA, popliteal, external iliac', 'anterior tibial, posterior tibial, peroneal']\n",
#  '\n',
#  'BMI:\n',
#  '[]\n',
#  'min value 13.99\n',
#  'max value 42.7\n',
#  '\n',
#  'Tobacco Use (1 current 2 former, 3 none):\n',
#  "['quit 1 to 10 years ago', 'current within the last year (  > or = 1 pack a day)', 'current within the last year ( < 1 pack a day)', 'Past, quit >10 year ago']\n",
#  '\n',
#  'Diabetes:\n',
#  '[1, 0]\n',
#  '\n',
#  'Hypertension:\n',
#  '[1, 0]\n',
#  '\n',
#  'Hyperlipidemia (choice=None):\n',
#  '[1, 0]\n',
#  '\n',
#  'Renal Status:\n',
#  "['GFR 60 to 89', 'Normal', 'GFR 30 to 59', 'Evidence of renal dysfunction ( GFR >90)', 'GFR<15 or patient is on dialysis', 'GFR 15 to 29']\n",
#  'min value 0\n',
#  'max value 1\n',
#  '\n',
#  'Coronary Artery Disease:\n',
#  "['Yes', 'No']\n",
#  '\n',
#  'History of MI:\n',
#  "['Yes', 'No']\n",
#  '\n',
#  'Functional impairment:\n',
#  '[0, 1]\n',
#  '\n',
#  'Clotting Disorder:\n',
#  '[1, 2, 0]\n',
#  '\n',
#  'Does Subject Currently have cancer?:\n',
#  "['No', 'Yes']\n",
#  '\n',
#  'Past hx of cancer:\n',
#  "['No', 'Yes']\n",
#  '\n',
#  'Hx of  DVT:\n',
#  "['No', 'Yes']\n",
#  '\n',
#  'Hx of stroke:\n',
#  "['Yes', 'No']\n",
#  '\n',
#  'Hx of pulmonary embolism:\n',
#  "['No', 'Yes']\n",
#  '\n',
#  'Does the patient have a history of solid organ transplant?:\n',
#  "['No', 'Yes']\n",
#  '\n',
#  'EGFR (mL/min/1.73m2):\n',
#  "['>60']\n",
#  'min value 0\n',
#  'max value 59\n',
#  '\n',
#  'Has subject had previous intervention of the index limb? :\n',
#  "['No', 'Yes']\n",
#  'min value 0\n',
#  'max value 0\n',
#  '\n',
#  'Previous occluded stents:\n',
#  "['Yes', 'No']\n",
#  'min value 0\n',
#  'max value 0\n',
#  '\n',
#  'Rutherford Score:\n',
#  "['not available']\n",
#  'min value 0\n',
#  'max value 6\n',
#  '\n',
#  'ABI Right:\n',
#  "['NC', '1.57 (Non-compressible) ', 'not available', 'N/A BKA', 'nc', 'non-compressible', 'none - hx AKA', 'BKA', 'not done', 'none']\n",
#  'min value 0.17\n',
#  'max value 1.68\n',
#  '\n',
#  'ABI left:\n',
#  "['NC', '1.32 (Non-compressible)', 'NONE', 'N/A AKA', 'nc', 'not available', 'non-compressible', 'inaudible', 'non-compressible ', 'not done', 'none', 'undetectable']\n",
#  'min value 0\n',
#  'max value 1.85\n',
#  '\n',
#  'Intervention Classification:\n',
#  "['Endo', 'Open', 'Combined']\n",
#  '\n',
#  'Intervention Type:\n',
#  "['angioplasty', 'bypass', 'angioplasty, stent, endarterectomy', 'endarterectomy', 'angioplasty, stent', 'stent', 'endarterectomy, bypass', 'angioplasty, endarterectomy', 'stent, endarterectomy', 'DVA', 'angioplasty, bypass', 'angioplasty, endarterectomy, bypass', 'stent, thrombectomy', 'bypass, bypass revision', 'bypass revision', 'angioplasty, stent, DVA', 'angioplasty', 'endarterectomy', 'stent, thrombectomy', 'bypass, bypass revision', 'stent, endarterectomy', 'bypass', 'angioplasty, bypass', 'DVA', 'angioplasty, stent, endarterectomy', 'angioplasty, stent']\n",
#  '\n',
#  'Record ID:\n',
#  "['T21-2', 'T21-3', 'T21-4', 'T21-5', 'T21-7', 'T21-9', 'T21-10', 'T21-12', 'T21-13', 'T21-14', 'T21-15', 'T21-16', 'T21-17', 'T21-18', 'T21-19', 'T21-22', 'T21-23', 'T21-24', 'T21-25', 'T21-26', 'T21-27', 'T21-28', 'T21-29', 'T21-30', 'T21-31', 'T21-32', 'T21-33', 'T21-34', 'T21-35', 'T21-36', 'T21-37', 'T21-39', 'T21-40', 'T21-41', 'T21-42', 'T21-43', 'T21-44', 'T21-45', 'T21-46', 'T21-47', 'T21-48', 'T21-49', 'T21-50', 'T21-52', 'T21-53', 'T21-54', 'T21-55', 'T21-57', 'T21-58', 'T21-59', 'T21-60', 'T21-61', 'T21-62', 'T21-63', 'T21-64', 'T21-65', 'T21-66', 'T21-67', 'T21-68', 'T21-69', 'T21-70', 'T21-56']\n",
#  'min value 2\n',
#  'max value 195\n',
#  '\n',
#  'Visit Timepoint:\n',
#  "['Baseline', '6hr Post', 'PO Day 1 ( 4-36 hours)', 'PO Day 2', '1M PO', '3M PO', 'PO Day 4', '6M PO', 'PO day 5', 'PO Day 3', 'Enrollment + Baseline', '30 Day Post Procedure', '3 Month Post procedure', '6 month Post Procedure', 'Post Op day 1 (4-36 hours)', 'Post op Day 2( if applicable)', 'Readmission', 'Post Op Day 3( if applicable)', 'Post Op Day 5 ( if applicable)', 'Post Op Day 4 ( if applicable)']\n",
#  '\n',
#  'Antiplatelet Therapy within 7 Days:\n',
#  "['clopidogrel', 'aspirin, clopidogrel', 'aspirin', 'ticagrelor', 'clopidogrel, celecoxib', 'aspirin, ticagrelor']\n",
#  '\n',
#  'Anticoagulation within 24 Hours:\n',
#  "['heparin', 'apixaban', 'enoxaprin, heparin', 'enoxaprin', 'rivaroxaban', 'warfarin', 'heparin, apixaban', 'heparin, warfarin', 'enoxaprin, warfarin', 'heparin, rivaroxaban', 'warfarin (Coumadin)', 'rivaroxaban (Xarelto)', 'heparin (Calciparine)', 'apixaban (eliquis)', 'enoxaparin (Lovenox)']\n",
#  '\n',
#  'Statin within 24 Hours:\n',
#  "['Rosuvastatin', 'atorvastatin', 'Simvastatin', 'Pravastatin', 'Lovastatin']\n",
#  '\n',
#  'Cilostazol within 7 days:\n',
#  '[\'cilostazol\', ""]\n',
#  '\n',
#  'BP prior to blood draw_left:\n',
#  "['Not taken']\n",
#  'min value 60\n',
#  'max value 250\n',
#  '\n',
#  'BP prior to blood draw_right:\n',
#  "['Not taken']\n",
#  'min value 40\n',
#  'max value 200\n',
#  '\n',
#  'Reaction Time (R) in min:\n',
#  "['>17.0', 'inconclusive', '`0.3', '*', '>17', '> 17.0']\n",
#  'min value 0.9\n',
#  'max value 17\n',
#  '\n',
#  'Lysis at 30 min (LY30) in %:\n',
#  "['inconclusive', 'none', 'not available', '*', 'inconclusive machine error', 'inconclusive ']\n",
#  'min value 0\n',
#  'max value 19.1\n',
#  '\n',
#  'CRT Max amplitude (MA) in mm:\n',
#  "['<40.0', '>75.0', '6..1', 'inconclusive', '*', 'inconclusive machine error', '637']\n",
#  'min value 40\n',
#  'max value 75\n',
#  '\n',
#  'CFF Max Amplitude( MA) in mm:\n',
#  "['>52.0', '<4.0', 'inconclusive', '27.8`', '>52', '*', 'inconclusive machine error']\n",
#  'min value 5.1\n',
#  'max value 52.1\n',
#  '\n',
#  'HKH MA (mm):\n',
#  "['<42.0', '>71.0', 'inconclusive', '<42', '68..9', '68,7', '>71']\n",
#  'min value 4.6\n',
#  'max value 71.1\n',
#  '\n',
#  'ActF MA (mm):\n',
#  "['>30.0', '19,1', '>30', 'inconclusive', '<2.0', '> 30.0']\n",
#  'min value 1.8\n',
#  'max value 30.1\n',
#  '\n',
#  'ADP MA (mm):\n',
#  "['<10.0', 'inconclusive', '< 10.0', '41,2', '<1.0', '>72.0']\n",
#  'min value 9.9\n',
#  'max value 72\n',
#  '\n',
#  'AA MA(mm):\n',
#  "['<8.0', '< 8.0', '<8', 'inconclusive']\n",
#  'min value 8\n',
#  'max value 90\n',
#  '\n',
#  'ADP % Aggregation:\n',
#  "['inconclusive', '.', '*', 'inconclusive ', 'Inconclusive', 'imconclusive']\n",
#  'min value 0\n',
#  'max value 100\n',
#  '\n',
#  'ADP % Inhibition:\n',
#  "['inconclusive', '.', '*', 'Incoclusive', 'inconclusive ', 'Inconclusive']\n",
#  'min value 0\n',
#  'max value 100\n',
#  '\n',
#  'AA % Aggregation:\n',
#  "['inconclusive', '.', '*', 'inconclusive ', 'Inconclusive']\n",
#  'min value 0\n',
#  'max value 100\n',
#  '\n',
#  'AA % Inhibition:\n',
#  "['inconclusive', '89/3', '.', '*', 'inconclusive ', 'Inconclusive ']\n",
#  'min value 0\n',
#  'max value 370.4\n',
#  '\n',
#  'CK R(min):\n',
#  "['>17.0', 'inconclusive', '*', '>17']\n",
#  'min value 1.5\n',
#  'max value 606\n',
#  '\n',
#  'CK K (min):\n',
#  "['>5.0', 'inconclusive', 'none', '<5.0', '>5', '*']\n",
#  'min value 0.6\n',
#  'max value 14.6\n',
#  '\n',
#  'CK angle( deg):\n',
#  "['inconclusive', '<39.0', '< 39.0', '*']\n",
#  'min value 37.7\n',
#  'max value 83\n',
#  '\n',
#  'CK MA (mm):\n',
#  "['<40.0', '>75.0', 'inconclusive', '61..9', 'not available', '<40', '>75', '*']\n",
#  'min value 14.9\n',
#  'max value 74.2\n',
#  '\n',
#  'CRT MA(mm):\n',
#  "['<40.0', '>75', 'inconclusive', '>75.0', '< 40.0 ', '<40', '*', 'inconclusive machine error']\n",
#  'min value 40.6\n',
#  'max value 85.7\n',
#  '\n',
#  'CKH R (min):\n',
#  "['>17.0', 'inconclusive', '>17', '*', 'inconclusive machine error']\n",
#  'min value 1.5\n',
#  'max value 63.5\n',
#  '\n',
#  'CFF MA(mm):\n',
#  "['>52.0', 'inconclusive', '>52', '26/1', '<4.0', '*', 'inconclusive machine error']\n",
#  'min value 0.7\n',
#  'max value 52.1\n',
#  '\n',
#  'CFF FLEV(mg/dL):\n',
#  "['inconclusive', '476/3', '.', '*', 'inconclusive machine error']\n",
#  'min value 99.3\n',
#  'max value 2220.8\n',
#  '\n',
#  'HbA1c Baseline( within1 year of study start):\n',
#  '[]\n',
#  'min value 5.0\n',
#  'max value 11.1\n',
#  '\n',
#  'INR value:\n',
#  '[]\n',
#  'min value 0.8\n',
#  'max value 230.0\n',
#  '\n',
#  'aPTT:\n',
#  "['>150', '430' , '>150.0']\n",
#  'min value 13.3\n',
#  'max value 150\n',
#  '\n',
#  'PT value:\n',
#  '[]\n',
#  'min value 1.0\n',
#  'max value 39.1\n',
#  '\n',
#  'WBC in K/uL:\n',
#  '[]\n',
#  'min value 3.92\n',
#  'max value 26.31\n',
#  '\n',
#  'RBC (M/uL):\n',
#  '[]\n',
#  'min value 2.24\n',
#  'max value 6.42\n',
#  '\n',
#  'HGB(g/dL):\n',
#  '[]\n',
#  'min value 7.0\n',
#  'max value 19.3\n',
#  '\n',
#  'HCT %:\n',
#  '[]\n',
#  'min value 21.3\n',
#  'max value 57.3\n',
#  '\n',
#  'PLT(K/uL):\n',
#  '[]\n',
#  'min value 78.0\n',
#  'max value 624.0\n',
#  '\n',
#  'Record ID:\n',
#  "['T21-9', 'T21-12', 'T21-14', 'T21-15', 'T21-16', 'T21-17', 'T21-18', 'T21-24', 'T21-25', 'T21-27', 'T21-29', 'T21-35', 'T21-36', 'T21-39', 'T21-41', 'T21-57', 'T21-60', 'T21-62', 'T21-67']\n",
#  'min value 4\n',
#  'max value 194\n',
#  '\n',
#  'Event Name:\n',
#  "['Event reporting 1', 'Event reporting 2', 'Event reporting 3', 'Event reporting 4', 'Event reporting 5', 'Event reporting 6', 'Readmission 1', 'Event Reporting 1', 'Event Reporting 2', 'Readmission 2']\n",
#  '\n',
#  'Date of Event:\n',
#  'min value 1\n',
#  'max value 500\n',
#  '\n',
#  'Event Type:\n',
#  "['Bypass/Stent stenosis', 'Infection/Dehisence', 'Bypass/Stent occlusion', 'Bleeding event', 'Thrombotic event not related to stent', 'Death', 'Worsening/enlarging wound', 'Thrombotic event not related to the area intervened', 'Bypass occlusion', 'Infection/Dehiscence', 'Occlusion in the area of intervention', 'other']\n",
#  '\n']

# %%
# Parse the data from the text file
columns = []
column_spec = {}
for line in lines:
    line = line.strip()
    # If the line is empty, start a new section
    if not line:
        print("")
        if column_spec:
            columns.append(column_spec)
        column_spec = {}
    # If the line has : then it is the name of a column
    elif line.endswith(":"):
        column_name = line.replace(":","")
        column_name = column_name.strip()
        column_spec["name"] = column_name
        print("Column name:", column_name)

    # Otherwise it's describing
    else:
        # If line it's list
        if line.startswith("["):
            print(type(line), line)
            line = ast.literal_eval(line)
            if len(line) != 0:
                print('saved')
                column_spec['list'] = line

        # If line is min
        elif line.startswith("min"):
            print("min value", line)
            min_val = float(line.replace("min value",""))
            column_spec['min'] = min_val
        
        # If line is max
        elif line.startswith("max"):
            print("max value", line)
            max_val = float(line.replace("max value",""))
            column_spec['max'] = max_val
columns
# Out:
# Column name: Record ID
# <class 'str'> ['T21-2', 'T21-3', 'T21-4', 'T21-5', 'T21-7', 'T21-9', 'T21-10', 'T21-12', 'T21-13', 'T21-14', 'T21-15', 'T21-16', 'T21-17', 'T21-18', 'T21-19', 'T21-22', 'T21-23', 'T21-24', 'T21-25', 'T21-26', 'T21-27', 'T21-28', 'T21-29', 'T21-30', 'T21-31', 'T21-32', 'T21-33', 'T21-34', 'T21-35', 'T21-36', 'T21-37', 'T21-39', 'T21-40', 'T21-41', 'T21-42', 'T21-43', 'T21-44', 'T21-45', 'T21-46', 'T21-47', 'T21-48', 'T21-49', 'T21-50', 'T21-52', 'T21-53', 'T21-54', 'T21-55', 'T21-57', 'T21-58', 'T21-59', 'T21-60', 'T21-61', 'T21-62', 'T21-63', 'T21-64', 'T21-65', 'T21-66', 'T21-67', 'T21-68', 'T21-69', 'T21-70']
# saved
# min value min value 2
# max value max value 195
#
# Column name: Age
# min value min value 60
# max value max value 92
#
# Column name: Sex
# <class 'str'> ['Male', 'Female']
# saved
#
# Column name: White
# <class 'str'> [1, 0]
# saved
#
# Column name: Extremity
# <class 'str'> ['right', 'left', 'Bilateral']
# saved
#
# Column name: Artery affected
# <class 'str'> ['common femoral, anterior tibial, external iliac', 'SFA, anterior tibial, posterior tibial', 'SFA, popliteal', 'SFA, anterior tibial', 'common femoral, anterior tibial, posterior tibial', 'common femoral, SFA, aortoiliac', 'common femoral, SFA, popliteal, anterior tibial, posterior tibial, aortoiliac', 'common femoral, popliteal, posterior tibial, aortoiliac', 'common femoral, anterior tibial, aortoiliac', 'common femoral, anterior tibial', 'SFA, popliteal, anterior tibial, aortoiliac', 'common femoral, external iliac', 'common femoral, popliteal, anterior tibial', 'SFA', 'common femoral, SFA', 'SFA, popliteal, aortoiliac', 'common femoral, anterior tibial, posterior tibial, internal iliac', 'common femoral, posterior tibial, internal iliac', 'common femoral, popliteal', 'common femoral, SFA, anterior tibial, aortoiliac', 'common femoral, anterior tibial, external iliac, internal iliac', 'common femoral, SFA, popliteal', 'common femoral, internal iliac', 'SFA, anterior tibial, aortoiliac', 'SFA, external iliac', 'common femoral, external iliac, internal iliac', 'common femoral, anterior tibial, internal iliac', 'common femoral, SFA, popliteal, anterior tibial, aortoiliac', 'SFA, posterior tibial', 'SFA, aortoiliac', 'common femoral, popliteal, anterior tibial, aortoiliac', 'common femoral, SFA, popliteal, aortoiliac', 'SFA, internal iliac', 'common femoral, SFA, posterior tibial, aortoiliac', 'SFA, anterior tibial, posterior tibial, internal iliac', 'common femoral, popliteal, aortoiliac', 'common femoral, popliteal, anterior tibial, posterior tibial, external iliac', 'SFA, anterior tibial, posterior tibial, external iliac', 'SFA, popliteal, posterior tibial', 'SFA, popliteal, posterior tibial, aortoiliac', 'common femoral, SFA, popliteal, anterior tibial', 'SFA, external iliac, internal iliac', 'SFA, posterior tibial, external iliac', 'SFA, popliteal, anterior tibial, posterior tibial', 'common femoral', 'external iliac', 'common femoral, aortoiliac', 'common femoral, SFA, popliteal, anterior tibial, posterior tibial, internal iliac', 'popliteal', 'anterior tibial, posterior tibial', 'common femoral, SFA, external iliac', 'anterior tibial', 'common femoral, SFA, popliteal, posterior tibial, external iliac, internal iliac', 'popliteal, anterior tibial', 'SFA, popliteal, anterior tibial', 'common femoral, external iliac, aortoiliac', 'popliteal, anterior tibial, posterior tibial', 'popliteal, posterior tibial', 'aortoiliac', 'common femoral, SFA, popliteal, external iliac, aortoiliac', 'popliteal, anterior tibial, posterior tibial, peroneal', 'common femoral, SFA, popliteal, external iliac', 'anterior tibial, posterior tibial, peroneal']
# saved
#
# Column name: BMI
# <class 'str'> []
# min value min value 13.99
# max value max value 42.7
#
# Column name: Tobacco Use (1 current 2 former, 3 none)
# <class 'str'> ['quit 1 to 10 years ago', 'current within the last year (  > or = 1 pack a day)', 'current within the last year ( < 1 pack a day)', 'Past, quit >10 year ago']
# saved
#
# Column name: Diabetes
# <class 'str'> [1, 0]
# saved
#
# Column name: Hypertension
# <class 'str'> [1, 0]
# saved
#
# Column name: Hyperlipidemia (choice=None)
# <class 'str'> [1, 0]
# saved
#
# Column name: Renal Status
# <class 'str'> ['GFR 60 to 89', 'Normal', 'GFR 30 to 59', 'Evidence of renal dysfunction ( GFR >90)', 'GFR<15 or patient is on dialysis', 'GFR 15 to 29']
# saved
# min value min value 0
# max value max value 1
#
# Column name: Coronary Artery Disease
# <class 'str'> ['Yes', 'No']
# saved
#
# Column name: History of MI
# <class 'str'> ['Yes', 'No']
# saved
#
# Column name: Functional impairment
# <class 'str'> [0, 1]
# saved
#
# Column name: Clotting Disorder
# <class 'str'> [1, 2, 0]
# saved
#
# Column name: Does Subject Currently have cancer?
# <class 'str'> ['No', 'Yes']
# saved
#
# Column name: Past hx of cancer
# <class 'str'> ['No', 'Yes']
# saved
#
# Column name: Hx of  DVT
# <class 'str'> ['No', 'Yes']
# saved
#
# Column name: Hx of stroke
# <class 'str'> ['Yes', 'No']
# saved
#
# Column name: Hx of pulmonary embolism
# <class 'str'> ['No', 'Yes']
# saved
#
# Column name: Does the patient have a history of solid organ transplant?
# <class 'str'> ['No', 'Yes']
# saved
#
# Column name: EGFR (mL/min/1.73m2)
# <class 'str'> ['>60']
# saved
# min value min value 0
# max value max value 59
#
# Column name: Has subject had previous intervention of the index limb?
# <class 'str'> ['No', 'Yes']
# saved
# min value min value 0
# max value max value 0
#
# Column name: Previous occluded stents
# <class 'str'> ['Yes', 'No']
# saved
# min value min value 0
# max value max value 0
#
# Column name: Rutherford Score
# <class 'str'> ['not available']
# saved
# min value min value 0
# max value max value 6
#
# Column name: ABI Right
# <class 'str'> ['NC', '1.57 (Non-compressible) ', 'not available', 'N/A BKA', 'nc', 'non-compressible', 'none - hx AKA', 'BKA', 'not done', 'none']
# saved
# min value min value 0.17
# max value max value 1.68
#
# Column name: ABI left
# <class 'str'> ['NC', '1.32 (Non-compressible)', 'NONE', 'N/A AKA', 'nc', 'not available', 'non-compressible', 'inaudible', 'non-compressible ', 'not done', 'none', 'undetectable']
# saved
# min value min value 0
# max value max value 1.85
#
# Column name: Intervention Classification
# <class 'str'> ['Endo', 'Open', 'Combined']
# saved
#
# Column name: Intervention Type
# <class 'str'> ['angioplasty', 'bypass', 'angioplasty, stent, endarterectomy', 'endarterectomy', 'angioplasty, stent', 'stent', 'endarterectomy, bypass', 'angioplasty, endarterectomy', 'stent, endarterectomy', 'DVA', 'angioplasty, bypass', 'angioplasty, endarterectomy, bypass', 'stent, thrombectomy', 'bypass, bypass revision', 'bypass revision', 'angioplasty, stent, DVA', 'angioplasty', 'endarterectomy', 'stent, thrombectomy', 'bypass, bypass revision', 'stent, endarterectomy', 'bypass', 'angioplasty, bypass', 'DVA', 'angioplasty, stent, endarterectomy', 'angioplasty, stent']
# saved
#
# Column name: Record ID
# <class 'str'> ['T21-2', 'T21-3', 'T21-4', 'T21-5', 'T21-7', 'T21-9', 'T21-10', 'T21-12', 'T21-13', 'T21-14', 'T21-15', 'T21-16', 'T21-17', 'T21-18', 'T21-19', 'T21-22', 'T21-23', 'T21-24', 'T21-25', 'T21-26', 'T21-27', 'T21-28', 'T21-29', 'T21-30', 'T21-31', 'T21-32', 'T21-33', 'T21-34', 'T21-35', 'T21-36', 'T21-37', 'T21-39', 'T21-40', 'T21-41', 'T21-42', 'T21-43', 'T21-44', 'T21-45', 'T21-46', 'T21-47', 'T21-48', 'T21-49', 'T21-50', 'T21-52', 'T21-53', 'T21-54', 'T21-55', 'T21-57', 'T21-58', 'T21-59', 'T21-60', 'T21-61', 'T21-62', 'T21-63', 'T21-64', 'T21-65', 'T21-66', 'T21-67', 'T21-68', 'T21-69', 'T21-70', 'T21-56']
# saved
# min value min value 2
# max value max value 195
#
# Column name: Visit Timepoint
# <class 'str'> ['Baseline', '6hr Post', 'PO Day 1 ( 4-36 hours)', 'PO Day 2', '1M PO', '3M PO', 'PO Day 4', '6M PO', 'PO day 5', 'PO Day 3', 'Enrollment + Baseline', '30 Day Post Procedure', '3 Month Post procedure', '6 month Post Procedure', 'Post Op day 1 (4-36 hours)', 'Post op Day 2( if applicable)', 'Readmission', 'Post Op Day 3( if applicable)', 'Post Op Day 5 ( if applicable)', 'Post Op Day 4 ( if applicable)']
# saved
#
# Column name: Antiplatelet Therapy within 7 Days
# <class 'str'> ['clopidogrel', 'aspirin, clopidogrel', 'aspirin', 'ticagrelor', 'clopidogrel, celecoxib', 'aspirin, ticagrelor']
# saved
#
# Column name: Anticoagulation within 24 Hours
# <class 'str'> ['heparin', 'apixaban', 'enoxaprin, heparin', 'enoxaprin', 'rivaroxaban', 'warfarin', 'heparin, apixaban', 'heparin, warfarin', 'enoxaprin, warfarin', 'heparin, rivaroxaban', 'warfarin (Coumadin)', 'rivaroxaban (Xarelto)', 'heparin (Calciparine)', 'apixaban (eliquis)', 'enoxaparin (Lovenox)']
# saved
#
# Column name: Statin within 24 Hours
# <class 'str'> ['Rosuvastatin', 'atorvastatin', 'Simvastatin', 'Pravastatin', 'Lovastatin']
# saved
#
# Column name: Cilostazol within 7 days
# <class 'str'> ['cilostazol', ""]
# saved
#
# Column name: BP prior to blood draw_left
# <class 'str'> ['Not taken']
# saved
# min value min value 60
# max value max value 250
#
# Column name: BP prior to blood draw_right
# <class 'str'> ['Not taken']
# saved
# min value min value 40
# max value max value 200
#
# Column name: Reaction Time (R) in min
# <class 'str'> ['>17.0', 'inconclusive', '`0.3', '*', '>17', '> 17.0']
# saved
# min value min value 0.9
# max value max value 17
#
# Column name: Lysis at 30 min (LY30) in %
# <class 'str'> ['inconclusive', 'none', 'not available', '*', 'inconclusive machine error', 'inconclusive ']
# saved
# min value min value 0
# max value max value 19.1
#
# Column name: CRT Max amplitude (MA) in mm
# <class 'str'> ['<40.0', '>75.0', '6..1', 'inconclusive', '*', 'inconclusive machine error', '637']
# saved
# min value min value 40
# max value max value 75
#
# Column name: CFF Max Amplitude( MA) in mm
# <class 'str'> ['>52.0', '<4.0', 'inconclusive', '27.8`', '>52', '*', 'inconclusive machine error']
# saved
# min value min value 5.1
# max value max value 52.1
#
# Column name: HKH MA (mm)
# <class 'str'> ['<42.0', '>71.0', 'inconclusive', '<42', '68..9', '68,7', '>71']
# saved
# min value min value 4.6
# max value max value 71.1
#
# Column name: ActF MA (mm)
# <class 'str'> ['>30.0', '19,1', '>30', 'inconclusive', '<2.0', '> 30.0']
# saved
# min value min value 1.8
# max value max value 30.1
#
# Column name: ADP MA (mm)
# <class 'str'> ['<10.0', 'inconclusive', '< 10.0', '41,2', '<1.0', '>72.0']
# saved
# min value min value 9.9
# max value max value 72
#
# Column name: AA MA(mm)
# <class 'str'> ['<8.0', '< 8.0', '<8', 'inconclusive']
# saved
# min value min value 8
# max value max value 90
#
# Column name: ADP % Aggregation
# <class 'str'> ['inconclusive', '.', '*', 'inconclusive ', 'Inconclusive', 'imconclusive']
# saved
# min value min value 0
# max value max value 100
#
# Column name: ADP % Inhibition
# <class 'str'> ['inconclusive', '.', '*', 'Incoclusive', 'inconclusive ', 'Inconclusive']
# saved
# min value min value 0
# max value max value 100
#
# Column name: AA % Aggregation
# <class 'str'> ['inconclusive', '.', '*', 'inconclusive ', 'Inconclusive']
# saved
# min value min value 0
# max value max value 100
#
# Column name: AA % Inhibition
# <class 'str'> ['inconclusive', '89/3', '.', '*', 'inconclusive ', 'Inconclusive ']
# saved
# min value min value 0
# max value max value 370.4
#
# Column name: CK R(min)
# <class 'str'> ['>17.0', 'inconclusive', '*', '>17']
# saved
# min value min value 1.5
# max value max value 606
#
# Column name: CK K (min)
# <class 'str'> ['>5.0', 'inconclusive', 'none', '<5.0', '>5', '*']
# saved
# min value min value 0.6
# max value max value 14.6
#
# Column name: CK angle( deg)
# <class 'str'> ['inconclusive', '<39.0', '< 39.0', '*']
# saved
# min value min value 37.7
# max value max value 83
#
# Column name: CK MA (mm)
# <class 'str'> ['<40.0', '>75.0', 'inconclusive', '61..9', 'not available', '<40', '>75', '*']
# saved
# min value min value 14.9
# max value max value 74.2
#
# Column name: CRT MA(mm)
# <class 'str'> ['<40.0', '>75', 'inconclusive', '>75.0', '< 40.0 ', '<40', '*', 'inconclusive machine error']
# saved
# min value min value 40.6
# max value max value 85.7
#
# Column name: CKH R (min)
# <class 'str'> ['>17.0', 'inconclusive', '>17', '*', 'inconclusive machine error']
# saved
# min value min value 1.5
# max value max value 63.5
#
# Column name: CFF MA(mm)
# <class 'str'> ['>52.0', 'inconclusive', '>52', '26/1', '<4.0', '*', 'inconclusive machine error']
# saved
# min value min value 0.7
# max value max value 52.1
#
# Column name: CFF FLEV(mg/dL)
# <class 'str'> ['inconclusive', '476/3', '.', '*', 'inconclusive machine error']
# saved
# min value min value 99.3
# max value max value 2220.8
#
# Column name: HbA1c Baseline( within1 year of study start)
# <class 'str'> []
# min value min value 5.0
# max value max value 11.1
#
# Column name: INR value
# <class 'str'> []
# min value min value 0.8
# max value max value 230.0
#
# Column name: aPTT
# <class 'str'> ['>150', '430' , '>150.0']
# saved
# min value min value 13.3
# max value max value 150
#
# Column name: PT value
# <class 'str'> []
# min value min value 1.0
# max value max value 39.1
#
# Column name: WBC in K/uL
# <class 'str'> []
# min value min value 3.92
# max value max value 26.31
#
# Column name: RBC (M/uL)
# <class 'str'> []
# min value min value 2.24
# max value max value 6.42
#
# Column name: HGB(g/dL)
# <class 'str'> []
# min value min value 7.0
# max value max value 19.3
#
# Column name: HCT %
# <class 'str'> []
# min value min value 21.3
# max value max value 57.3
#
# Column name: PLT(K/uL)
# <class 'str'> []
# min value min value 78.0
# max value max value 624.0
#
# Column name: Record ID
# <class 'str'> ['T21-9', 'T21-12', 'T21-14', 'T21-15', 'T21-16', 'T21-17', 'T21-18', 'T21-24', 'T21-25', 'T21-27', 'T21-29', 'T21-35', 'T21-36', 'T21-39', 'T21-41', 'T21-57', 'T21-60', 'T21-62', 'T21-67']
# saved
# min value min value 4
# max value max value 194
#
# Column name: Event Name
# <class 'str'> ['Event reporting 1', 'Event reporting 2', 'Event reporting 3', 'Event reporting 4', 'Event reporting 5', 'Event reporting 6', 'Readmission 1', 'Event Reporting 1', 'Event Reporting 2', 'Readmission 2']
# saved
#
# Column name: Date of Event
# min value min value 1
# max value max value 500
#
# Column name: Event Type
# <class 'str'> ['Bypass/Stent stenosis', 'Infection/Dehisence', 'Bypass/Stent occlusion', 'Bleeding event', 'Thrombotic event not related to stent', 'Death', 'Worsening/enlarging wound', 'Thrombotic event not related to the area intervened', 'Bypass occlusion', 'Infection/Dehiscence', 'Occlusion in the area of intervention', 'other']
# saved
# [{'name': 'Record ID',
#   'list': ['T21-2',
#    'T21-3',
#    'T21-4',
#    'T21-5',
#    'T21-7',
#    'T21-9',
#    'T21-10',
#    'T21-12',
#    'T21-13',
#    'T21-14',
#    'T21-15',
#    'T21-16',
#    'T21-17',
#    'T21-18',
#    'T21-19',
#    'T21-22',
#    'T21-23',
#    'T21-24',
#    'T21-25',
#    'T21-26',
#    'T21-27',
#    'T21-28',
#    'T21-29',
#    'T21-30',
#    'T21-31',
#    'T21-32',
#    'T21-33',
#    'T21-34',
#    'T21-35',
#    'T21-36',
#    'T21-37',
#    'T21-39',
#    'T21-40',
#    'T21-41',
#    'T21-42',
#    'T21-43',
#    'T21-44',
#    'T21-45',
#    'T21-46',
#    'T21-47',
#    'T21-48',
#    'T21-49',
#    'T21-50',
#    'T21-52',
#    'T21-53',
#    'T21-54',
#    'T21-55',
#    'T21-57',
#    'T21-58',
#    'T21-59',
#    'T21-60',
#    'T21-61',
#    'T21-62',
#    'T21-63',
#    'T21-64',
#    'T21-65',
#    'T21-66',
#    'T21-67',
#    'T21-68',
#    'T21-69',
#    'T21-70'],
#   'min': 2.0,
#   'max': 195.0},
#  {'name': 'Age', 'min': 60.0, 'max': 92.0},
#  {'name': 'Sex', 'list': ['Male', 'Female']},
#  {'name': 'White', 'list': [1, 0]},
#  {'name': 'Extremity', 'list': ['right', 'left', 'Bilateral']},
#  {'name': 'Artery affected',
#   'list': ['common femoral, anterior tibial, external iliac',
#    'SFA, anterior tibial, posterior tibial',
#    'SFA, popliteal',
#    'SFA, anterior tibial',
#    'common femoral, anterior tibial, posterior tibial',
#    'common femoral, SFA, aortoiliac',
#    'common femoral, SFA, popliteal, anterior tibial, posterior tibial, aortoiliac',
#    'common femoral, popliteal, posterior tibial, aortoiliac',
#    'common femoral, anterior tibial, aortoiliac',
#    'common femoral, anterior tibial',
#    'SFA, popliteal, anterior tibial, aortoiliac',
#    'common femoral, external iliac',
#    'common femoral, popliteal, anterior tibial',
#    'SFA',
#    'common femoral, SFA',
#    'SFA, popliteal, aortoiliac',
#    'common femoral, anterior tibial, posterior tibial, internal iliac',
#    'common femoral, posterior tibial, internal iliac',
#    'common femoral, popliteal',
#    'common femoral, SFA, anterior tibial, aortoiliac',
#    'common femoral, anterior tibial, external iliac, internal iliac',
#    'common femoral, SFA, popliteal',
#    'common femoral, internal iliac',
#    'SFA, anterior tibial, aortoiliac',
#    'SFA, external iliac',
#    'common femoral, external iliac, internal iliac',
#    'common femoral, anterior tibial, internal iliac',
#    'common femoral, SFA, popliteal, anterior tibial, aortoiliac',
#    'SFA, posterior tibial',
#    'SFA, aortoiliac',
#    'common femoral, popliteal, anterior tibial, aortoiliac',
#    'common femoral, SFA, popliteal, aortoiliac',
#    'SFA, internal iliac',
#    'common femoral, SFA, posterior tibial, aortoiliac',
#    'SFA, anterior tibial, posterior tibial, internal iliac',
#    'common femoral, popliteal, aortoiliac',
#    'common femoral, popliteal, anterior tibial, posterior tibial, external iliac',
#    'SFA, anterior tibial, posterior tibial, external iliac',
#    'SFA, popliteal, posterior tibial',
#    'SFA, popliteal, posterior tibial, aortoiliac',
#    'common femoral, SFA, popliteal, anterior tibial',
#    'SFA, external iliac, internal iliac',
#    'SFA, posterior tibial, external iliac',
#    'SFA, popliteal, anterior tibial, posterior tibial',
#    'common femoral',
#    'external iliac',
#    'common femoral, aortoiliac',
#    'common femoral, SFA, popliteal, anterior tibial, posterior tibial, internal iliac',
#    'popliteal',
#    'anterior tibial, posterior tibial',
#    'common femoral, SFA, external iliac',
#    'anterior tibial',
#    'common femoral, SFA, popliteal, posterior tibial, external iliac, internal iliac',
#    'popliteal, anterior tibial',
#    'SFA, popliteal, anterior tibial',
#    'common femoral, external iliac, aortoiliac',
#    'popliteal, anterior tibial, posterior tibial',
#    'popliteal, posterior tibial',
#    'aortoiliac',
#    'common femoral, SFA, popliteal, external iliac, aortoiliac',
#    'popliteal, anterior tibial, posterior tibial, peroneal',
#    'common femoral, SFA, popliteal, external iliac',
#    'anterior tibial, posterior tibial, peroneal']},
#  {'name': 'BMI', 'min': 13.99, 'max': 42.7},
#  {'name': 'Tobacco Use (1 current 2 former, 3 none)',
#   'list': ['quit 1 to 10 years ago',
#    'current within the last year (  > or = 1 pack a day)',
#    'current within the last year ( < 1 pack a day)',
#    'Past, quit >10 year ago']},
#  {'name': 'Diabetes', 'list': [1, 0]},
#  {'name': 'Hypertension', 'list': [1, 0]},
#  {'name': 'Hyperlipidemia (choice=None)', 'list': [1, 0]},
#  {'name': 'Renal Status',
#   'list': ['GFR 60 to 89',
#    'Normal',
#    'GFR 30 to 59',
#    'Evidence of renal dysfunction ( GFR >90)',
#    'GFR<15 or patient is on dialysis',
#    'GFR 15 to 29'],
#   'min': 0.0,
#   'max': 1.0},
#  {'name': 'Coronary Artery Disease', 'list': ['Yes', 'No']},
#  {'name': 'History of MI', 'list': ['Yes', 'No']},
#  {'name': 'Functional impairment', 'list': [0, 1]},
#  {'name': 'Clotting Disorder', 'list': [1, 2, 0]},
#  {'name': 'Does Subject Currently have cancer?', 'list': ['No', 'Yes']},
#  {'name': 'Past hx of cancer', 'list': ['No', 'Yes']},
#  {'name': 'Hx of  DVT', 'list': ['No', 'Yes']},
#  {'name': 'Hx of stroke', 'list': ['Yes', 'No']},
#  {'name': 'Hx of pulmonary embolism', 'list': ['No', 'Yes']},
#  {'name': 'Does the patient have a history of solid organ transplant?',
#   'list': ['No', 'Yes']},
#  {'name': 'EGFR (mL/min/1.73m2)', 'list': ['>60'], 'min': 0.0, 'max': 59.0},
#  {'name': 'Has subject had previous intervention of the index limb?',
#   'list': ['No', 'Yes'],
#   'min': 0.0,
#   'max': 0.0},
#  {'name': 'Previous occluded stents',
#   'list': ['Yes', 'No'],
#   'min': 0.0,
#   'max': 0.0},
#  {'name': 'Rutherford Score',
#   'list': ['not available'],
#   'min': 0.0,
#   'max': 6.0},
#  {'name': 'ABI Right',
#   'list': ['NC',
#    '1.57 (Non-compressible) ',
#    'not available',
#    'N/A BKA',
#    'nc',
#    'non-compressible',
#    'none - hx AKA',
#    'BKA',
#    'not done',
#    'none'],
#   'min': 0.17,
#   'max': 1.68},
#  {'name': 'ABI left',
#   'list': ['NC',
#    '1.32 (Non-compressible)',
#    'NONE',
#    'N/A AKA',
#    'nc',
#    'not available',
#    'non-compressible',
#    'inaudible',
#    'non-compressible ',
#    'not done',
#    'none',
#    'undetectable'],
#   'min': 0.0,
#   'max': 1.85},
#  {'name': 'Intervention Classification', 'list': ['Endo', 'Open', 'Combined']},
#  {'name': 'Intervention Type',
#   'list': ['angioplasty',
#    'bypass',
#    'angioplasty, stent, endarterectomy',
#    'endarterectomy',
#    'angioplasty, stent',
#    'stent',
#    'endarterectomy, bypass',
#    'angioplasty, endarterectomy',
#    'stent, endarterectomy',
#    'DVA',
#    'angioplasty, bypass',
#    'angioplasty, endarterectomy, bypass',
#    'stent, thrombectomy',
#    'bypass, bypass revision',
#    'bypass revision',
#    'angioplasty, stent, DVA',
#    'angioplasty',
#    'endarterectomy',
#    'stent, thrombectomy',
#    'bypass, bypass revision',
#    'stent, endarterectomy',
#    'bypass',
#    'angioplasty, bypass',
#    'DVA',
#    'angioplasty, stent, endarterectomy',
#    'angioplasty, stent']},
#  {'name': 'Record ID',
#   'list': ['T21-2',
#    'T21-3',
#    'T21-4',
#    'T21-5',
#    'T21-7',
#    'T21-9',
#    'T21-10',
#    'T21-12',
#    'T21-13',
#    'T21-14',
#    'T21-15',
#    'T21-16',
#    'T21-17',
#    'T21-18',
#    'T21-19',
#    'T21-22',
#    'T21-23',
#    'T21-24',
#    'T21-25',
#    'T21-26',
#    'T21-27',
#    'T21-28',
#    'T21-29',
#    'T21-30',
#    'T21-31',
#    'T21-32',
#    'T21-33',
#    'T21-34',
#    'T21-35',
#    'T21-36',
#    'T21-37',
#    'T21-39',
#    'T21-40',
#    'T21-41',
#    'T21-42',
#    'T21-43',
#    'T21-44',
#    'T21-45',
#    'T21-46',
#    'T21-47',
#    'T21-48',
#    'T21-49',
#    'T21-50',
#    'T21-52',
#    'T21-53',
#    'T21-54',
#    'T21-55',
#    'T21-57',
#    'T21-58',
#    'T21-59',
#    'T21-60',
#    'T21-61',
#    'T21-62',
#    'T21-63',
#    'T21-64',
#    'T21-65',
#    'T21-66',
#    'T21-67',
#    'T21-68',
#    'T21-69',
#    'T21-70',
#    'T21-56'],
#   'min': 2.0,
#   'max': 195.0},
#  {'name': 'Visit Timepoint',
#   'list': ['Baseline',
#    '6hr Post',
#    'PO Day 1 ( 4-36 hours)',
#    'PO Day 2',
#    '1M PO',
#    '3M PO',
#    'PO Day 4',
#    '6M PO',
#    'PO day 5',
#    'PO Day 3',
#    'Enrollment + Baseline',
#    '30 Day Post Procedure',
#    '3 Month Post procedure',
#    '6 month Post Procedure',
#    'Post Op day 1 (4-36 hours)',
#    'Post op Day 2( if applicable)',
#    'Readmission',
#    'Post Op Day 3( if applicable)',
#    'Post Op Day 5 ( if applicable)',
#    'Post Op Day 4 ( if applicable)']},
#  {'name': 'Antiplatelet Therapy within 7 Days',
#   'list': ['clopidogrel',
#    'aspirin, clopidogrel',
#    'aspirin',
#    'ticagrelor',
#    'clopidogrel, celecoxib',
#    'aspirin, ticagrelor']},
#  {'name': 'Anticoagulation within 24 Hours',
#   'list': ['heparin',
#    'apixaban',
#    'enoxaprin, heparin',
#    'enoxaprin',
#    'rivaroxaban',
#    'warfarin',
#    'heparin, apixaban',
#    'heparin, warfarin',
#    'enoxaprin, warfarin',
#    'heparin, rivaroxaban',
#    'warfarin (Coumadin)',
#    'rivaroxaban (Xarelto)',
#    'heparin (Calciparine)',
#    'apixaban (eliquis)',
#    'enoxaparin (Lovenox)']},
#  {'name': 'Statin within 24 Hours',
#   'list': ['Rosuvastatin',
#    'atorvastatin',
#    'Simvastatin',
#    'Pravastatin',
#    'Lovastatin']},
#  {'name': 'Cilostazol within 7 days', 'list': ['cilostazol', '']},
#  {'name': 'BP prior to blood draw_left',
#   'list': ['Not taken'],
#   'min': 60.0,
#   'max': 250.0},
#  {'name': 'BP prior to blood draw_right',
#   'list': ['Not taken'],
#   'min': 40.0,
#   'max': 200.0},
#  {'name': 'Reaction Time (R) in min',
#   'list': ['>17.0', 'inconclusive', '`0.3', '*', '>17', '> 17.0'],
#   'min': 0.9,
#   'max': 17.0},
#  {'name': 'Lysis at 30 min (LY30) in %',
#   'list': ['inconclusive',
#    'none',
#    'not available',
#    '*',
#    'inconclusive machine error',
#    'inconclusive '],
#   'min': 0.0,
#   'max': 19.1},
#  {'name': 'CRT Max amplitude (MA) in mm',
#   'list': ['<40.0',
#    '>75.0',
#    '6..1',
#    'inconclusive',
#    '*',
#    'inconclusive machine error',
#    '637'],
#   'min': 40.0,
#   'max': 75.0},
#  {'name': 'CFF Max Amplitude( MA) in mm',
#   'list': ['>52.0',
#    '<4.0',
#    'inconclusive',
#    '27.8`',
#    '>52',
#    '*',
#    'inconclusive machine error'],
#   'min': 5.1,
#   'max': 52.1},
#  {'name': 'HKH MA (mm)',
#   'list': ['<42.0', '>71.0', 'inconclusive', '<42', '68..9', '68,7', '>71'],
#   'min': 4.6,
#   'max': 71.1},
#  {'name': 'ActF MA (mm)',
#   'list': ['>30.0', '19,1', '>30', 'inconclusive', '<2.0', '> 30.0'],
#   'min': 1.8,
#   'max': 30.1},
#  {'name': 'ADP MA (mm)',
#   'list': ['<10.0', 'inconclusive', '< 10.0', '41,2', '<1.0', '>72.0'],
#   'min': 9.9,
#   'max': 72.0},
#  {'name': 'AA MA(mm)',
#   'list': ['<8.0', '< 8.0', '<8', 'inconclusive'],
#   'min': 8.0,
#   'max': 90.0},
#  {'name': 'ADP % Aggregation',
#   'list': ['inconclusive',
#    '.',
#    '*',
#    'inconclusive ',
#    'Inconclusive',
#    'imconclusive'],
#   'min': 0.0,
#   'max': 100.0},
#  {'name': 'ADP % Inhibition',
#   'list': ['inconclusive',
#    '.',
#    '*',
#    'Incoclusive',
#    'inconclusive ',
#    'Inconclusive'],
#   'min': 0.0,
#   'max': 100.0},
#  {'name': 'AA % Aggregation',
#   'list': ['inconclusive', '.', '*', 'inconclusive ', 'Inconclusive'],
#   'min': 0.0,
#   'max': 100.0},
#  {'name': 'AA % Inhibition',
#   'list': ['inconclusive', '89/3', '.', '*', 'inconclusive ', 'Inconclusive '],
#   'min': 0.0,
#   'max': 370.4},
#  {'name': 'CK R(min)',
#   'list': ['>17.0', 'inconclusive', '*', '>17'],
#   'min': 1.5,
#   'max': 606.0},
#  {'name': 'CK K (min)',
#   'list': ['>5.0', 'inconclusive', 'none', '<5.0', '>5', '*'],
#   'min': 0.6,
#   'max': 14.6},
#  {'name': 'CK angle( deg)',
#   'list': ['inconclusive', '<39.0', '< 39.0', '*'],
#   'min': 37.7,
#   'max': 83.0},
#  {'name': 'CK MA (mm)',
#   'list': ['<40.0',
#    '>75.0',
#    'inconclusive',
#    '61..9',
#    'not available',
#    '<40',
#    '>75',
#    '*'],
#   'min': 14.9,
#   'max': 74.2},
#  {'name': 'CRT MA(mm)',
#   'list': ['<40.0',
#    '>75',
#    'inconclusive',
#    '>75.0',
#    '< 40.0 ',
#    '<40',
#    '*',
#    'inconclusive machine error'],
#   'min': 40.6,
#   'max': 85.7},
#  {'name': 'CKH R (min)',
#   'list': ['>17.0', 'inconclusive', '>17', '*', 'inconclusive machine error'],
#   'min': 1.5,
#   'max': 63.5},
#  {'name': 'CFF MA(mm)',
#   'list': ['>52.0',
#    'inconclusive',
#    '>52',
#    '26/1',
#    '<4.0',
#    '*',
#    'inconclusive machine error'],
#   'min': 0.7,
#   'max': 52.1},
#  {'name': 'CFF FLEV(mg/dL)',
#   'list': ['inconclusive', '476/3', '.', '*', 'inconclusive machine error'],
#   'min': 99.3,
#   'max': 2220.8},
#  {'name': 'HbA1c Baseline( within1 year of study start)',
#   'min': 5.0,
#   'max': 11.1},
#  {'name': 'INR value', 'min': 0.8, 'max': 230.0},
#  {'name': 'aPTT',
#   'list': ['>150', '430', '>150.0'],
#   'min': 13.3,
#   'max': 150.0},
#  {'name': 'PT value', 'min': 1.0, 'max': 39.1},
#  {'name': 'WBC in K/uL', 'min': 3.92, 'max': 26.31},
#  {'name': 'RBC (M/uL)', 'min': 2.24, 'max': 6.42},
#  {'name': 'HGB(g/dL)', 'min': 7.0, 'max': 19.3},
#  {'name': 'HCT %', 'min': 21.3, 'max': 57.3},
#  {'name': 'PLT(K/uL)', 'min': 78.0, 'max': 624.0},
#  {'name': 'Record ID',
#   'list': ['T21-9',
#    'T21-12',
#    'T21-14',
#    'T21-15',
#    'T21-16',
#    'T21-17',
#    'T21-18',
#    'T21-24',
#    'T21-25',
#    'T21-27',
#    'T21-29',
#    'T21-35',
#    'T21-36',
#    'T21-39',
#    'T21-41',
#    'T21-57',
#    'T21-60',
#    'T21-62',
#    'T21-67'],
#   'min': 4.0,
#   'max': 194.0},
#  {'name': 'Event Name',
#   'list': ['Event reporting 1',
#    'Event reporting 2',
#    'Event reporting 3',
#    'Event reporting 4',
#    'Event reporting 5',
#    'Event reporting 6',
#    'Readmission 1',
#    'Event Reporting 1',
#    'Event Reporting 2',
#    'Readmission 2']},
#  {'name': 'Date of Event', 'min': 1.0, 'max': 500.0},
#  {'name': 'Event Type',
#   'list': ['Bypass/Stent stenosis',
#    'Infection/Dehisence',
#    'Bypass/Stent occlusion',
#    'Bleeding event',
#    'Thrombotic event not related to stent',
#    'Death',
#    'Worsening/enlarging wound',
#    'Thrombotic event not related to the area intervened',
#    'Bypass occlusion',
#    'Infection/Dehiscence',
#    'Occlusion in the area of intervention',
#    'other']}]

# %%
# Create the Excel workbook and sheets
workbook = Workbook()
sheet1 = workbook.active
sheet1.title = "Baseline"
sheet2 = workbook.create_sheet(title="TEG Values")
sheet3 = workbook.create_sheet(title="Events")

# %%
# Generate and add data to the sheets
data1 = {}
for col in columns[:30]:
    values = []
    for _ in range(80):
        values.append(generate_data(col))
    data1[col['name']] = values
df1 = pd.DataFrame(data1)

data2 = {}
for col in columns[30:67]:
    values = []
    sheet2.append([col['name']])
    for _ in range(800):
        values.append(generate_data(col))
    data2[col['name']] = values
df2 = pd.DataFrame(data2)

data3 = {}
for col in columns[67:]:
    print(col)
    values = []
    sheet3.append([col['name']])
    for _ in range(150):
        values.append(generate_data(col))
    data3[col['name']] = values
df3 = pd.DataFrame(data3)
# Out:
# {'name': 'Record ID', 'list': ['T21-9', 'T21-12', 'T21-14', 'T21-15', 'T21-16', 'T21-17', 'T21-18', 'T21-24', 'T21-25', 'T21-27', 'T21-29', 'T21-35', 'T21-36', 'T21-39', 'T21-41', 'T21-57', 'T21-60', 'T21-62', 'T21-67'], 'min': 4.0, 'max': 194.0}
# {'name': 'Event Name', 'list': ['Event reporting 1', 'Event reporting 2', 'Event reporting 3', 'Event reporting 4', 'Event reporting 5', 'Event reporting 6', 'Readmission 1', 'Event Reporting 1', 'Event Reporting 2', 'Readmission 2']}
# {'name': 'Date of Event', 'min': 1.0, 'max': 500.0}
# {'name': 'Event Type', 'list': ['Bypass/Stent stenosis', 'Infection/Dehisence', 'Bypass/Stent occlusion', 'Bleeding event', 'Thrombotic event not related to stent', 'Death', 'Worsening/enlarging wound', 'Thrombotic event not related to the area intervened', 'Bypass occlusion', 'Infection/Dehiscence', 'Occlusion in the area of intervention', 'other']}

# %%
# Combine blood pressure column
# Combine the "BP prior to blood draw_left" and "BP prior to blood draw_right" columns
df2['BP prior to blood draw'] = df2['BP prior to blood draw_left'].astype(str) + '/' + df2['BP prior to blood draw_right'].astype(str)

# Delete Not taken rows
df2['BP prior to blood draw'] = df2['BP prior to blood draw'].apply(lambda x: "Not taken" if "Not taken" in x else x)

# Drop the original columns
df2.drop(['BP prior to blood draw_left', 'BP prior to blood draw_right'], axis=1, inplace=True)

# %%
# Filter the DataFrame to keep only rows with unique "Record ID" values in df1
df1.drop_duplicates(subset="Record ID", keep=False, inplace=True)

# %%
# Only keep values from df1 Record ID, those are the only patients that exist.

# Copy values from df1 to df2 and df3 as needed
for i in range(len(df2)):
    df2.iloc[i, df2.columns.get_loc('Record ID')] = df1.iloc[i % len(df1), df1.columns.get_loc('Record ID')]

for i in range(len(df3)):
    df3.iloc[i, df2.columns.get_loc('Record ID')] = df1.iloc[int(random.uniform(0,len(df1))), df1.columns.get_loc('Record ID')]

# %%
# Save the Excel file
# Create an ExcelWriter object to save the DataFrames to an Excel file
with pd.ExcelWriter('./data/New_Dummy_Data.xlsx', engine='xlsxwriter') as writer:
    df1.to_excel(writer, sheet_name='Baseline', index=False)
    df2.to_excel(writer, sheet_name='TEG Values', index=False)
    df3.to_excel(writer, sheet_name='Events', index=False)
